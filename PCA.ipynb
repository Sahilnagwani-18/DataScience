# %%
import cv2

img = cv2.imread('att_faces/s1/1.pgm', cv2.IMREAD_GRAYSCALE)
print(img.shape)  
print(img)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import cv2
#       3 img = cv2.imread('att_faces/s1/1.pgm', cv2.IMREAD_GRAYSCALE)
#       4 print(img.shape)
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement cv2-python (from versions: none)
# ERROR: No matching distribution found for cv2-python
